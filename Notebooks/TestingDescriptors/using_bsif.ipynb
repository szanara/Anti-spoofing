# %%
from pre_processing import*

# %%
from bsif import *

# %%
import cv2
import os
import matplotlib.pyplot as plt

# %%
path2read = '/home/mds3/Downloads/Visao Computacional-20240430T145425Z-001/LCC_FASD/LCC_FASD_training/real/'

# %%
image= cv2.imread(path2read+'YOUTUBE_id47_s3_150.png')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
c = ProcessingImage(image_rgb)

# %%
[ch1_hsv, ch2_hsv, ch3_hsv],[ch1_ycbcr, ch2_ycbcr, ch3_ycbcr] =c.extractor()

# %%
features_hsv = []
for channel in [ch1_hsv, ch2_hsv, ch3_hsv]:
    Bsif = BSIF(channel)
    features = Bsif.bsif()
    features_hsv.append(features)
    Bsif.visualize_bsif_codes()

# %%
features_ycbcr= []
for channel in [ch1_ycbcr, ch2_ycbcr, ch3_ycbcr]:
    Bsif = BSIF(channel)
    features = Bsif.bsif()
    features_ycbcr.append(features)
    Bsif.visualize_bsif_codes()

# %%
fatures_ycbcr = np.concatenate(np.array(features_ycbcr),axis=1)
features_hsv = np.concatenate(np.array(features_hsv),axis=1)

# %%
features_all = np.concatenate((fatures_ycbcr, features_hsv ), axis=1)

# %%
features_all.shape
# Out:
# (64, 384, 8)
